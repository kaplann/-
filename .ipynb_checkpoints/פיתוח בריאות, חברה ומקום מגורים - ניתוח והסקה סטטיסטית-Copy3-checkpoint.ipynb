# %% [markdown]
# <h1> בריאות, חברה ומקום מגורים: תובנות בנושא אי-שוויון ורשויות מקומיות</h1>
#
# <h3>
#  ניתוח סטטיסטי וויזואליצזיה של מאפיינים חשובים ע"פ נתוני פרופיל בריאותי-חברתי של היישובים בישראל
# 2009-2005
# </h3>

# %%
from helper_functions import *
Image(filename='pictures/flyer_header_wide.png', width=1000, height=1000)

# %% [markdown]
# <div style="direction:rtl">  יוצרים: </div>
# <h5>   noam.kaplan85@gmail.com, 054-2241244 - נועם קפלן  </h5>
# <h5> shalom.toledo@gmail.com - שלום טולדו  </h5>
# <h5> illyab@post.bgu.ac.il - איליה ברודר </h5>

# %% [markdown]
# <h2> מבוא </h2>

# %% [markdown]
# <div style="direction:rtl"> <br>
# במסמך זה מתועד ומוסבר תהליך של כריית נתונים וניתוחם בכלים סטטיסטיים מתחום הלמידה החישובית. בנוסף, מוצג במסמך קוד הפייתון איתו ניתחנו את קובץ האקסל שפורסם ע"י הלשכה המרכזית לסטטיסטיקה, מהלך המחקר ותוצאותיו, לרבות ויזואליזציות אינטרקטיביות שונות.
# <br />
# </div>
#
# <div style="direction:rtl"> <br>
# כנקודת מוצא לפרוייקט בחרנו לגשת לבעיה בכלים מתמטיים והנדסיים בלבד, ללא עירוב של אינטואיציות אישיות של המעורבים. בחרנו בגישה זו כדי לוודא שאין פגמים בתהליך ניתוח המידע ולא נוצרה הטייה בתוצר שחישבנו ובמסקנות שאנו מספקים לאור מידע זה.
# <br/>
# </div>

# %% [markdown]
# <h7> הערה חשובה: כל הגרפים המוצגים במסמך זה אינטרקטיביים. מומלץ לעבור בין הלשוניות השונות ולשים את העכבר מעל נקודות שונות בגרף כדי לקבל מידע נוסף </h7>

# %% [markdown]
# <a id="top"></a>

# %% [markdown]
# <h1> :תוכן עניינים  </h1>
#
#  [מבוא](#מבוא)
# - [1. סקירה מהירה של העיבוד המקדים](#d1.)
#     - [1.1. סקירת המידע הגולמי](#d1.1.)

# %%
output_notebook() # Bokeh
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d399b786-3c79-4354-938f-43c07c93ec5b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# <h3> קריאת המידע </h3>
# <div style="direction:rtl">
# ישנן שש לשוניות שונות בקובץ האקסל שפורסם לתחרות. למטה מוצגות הלשוניות השונות (בעמודה Sheets)  ומספר העמודות (features) בכל אחת. לכרטיסיות השונות ישנן מספר שונה של עמודות, כפי שניתן לראות בטבלה מתחת. </div>
# <div style="direction:rtl">
# ניתן לגשת לטבלה המלאה בקישור
# <a href="https://drive.google.com/open?id=0B7eezotEK_oPWEVjazI2Rzd4Q1k">הזה.</a>
#
#
# </div>

# %%
# Read Data: 
df = pd.read_excel('Data/Unprocessed_Data/profi_h.xlsx', sheetname=None)
sheets = sorted(list(df.keys()))

# %%
num_feats = [len(df[s].keys()) for s in sheets]
sheets_stats_dict = {'Sheets': sheets, 'Number of features': num_feats}
col_order = ['Sheets', 'Number of featers']
sheet_stats = pd.DataFrame(sheets_stats_dict)
sheet_stats.reindex_axis(['Sheets', 'Number of features'], axis=1)
# Out:
#                             Sheets  Number of features
# 0   יישובים בינוניים (2,000-9,999)                 108
# 1                        קובץ ארצי                 344
# 2   קובץ יישובים גדולים (10,000 +)                 352
# 3             קובץ מועצות איזוריות                 148
# 4                      קובץ מחוזות                 347
# 5                        קובץ נפות                 347

# %% [markdown]
# <div style="direction:rtl"> <br >
# קובץ המידע השלם על כלל לשונותיו אינו ידידותי במיוחד. לטובת הקורא שאינו מכיר את המידע נציג חלק מהעמודות של כרטיסיה אחת לדוגמא.
# <br />
# </div>
# <div style="direction:rtl"> <br >
# כרטיסיה לדוגמא:  "	יישובים בינוניים (2,000-9,999)"
# <br />
# </div>

# %%
sheet_translator = create_sheet_translator(sheet_stats)

# %%
sheet_i = sheet_translator['SmallTown']
print('View sheet %s.' % str(sheets[sheet_i]))
df[sheets[sheet_i]][:10].style.highlight_null(null_color='red')
# Out:
# View sheet  יישובים בינוניים (2,000-9,999).
#         <style  type="text/css" >
#
#
#             #T_6ffbad1a_8622_11e6_bb04_642737f035d1row5_col100 {
#
#                 background-color:  red;
#
#             }
#
#             #T_6ffbad1a_8622_11e6_bb04_642737f035d1row6_col4 {
#
#                 background-color:  red;
#
#             }
#
#             #T_6ffbad1a_8622_11e6_bb04_642737f035d1row6_col5 {
#
#                 background-color:  red;
#
#             }
#
#             #T_6ffbad1a_8622_11e6_bb04_642737f035d1row6_col94 {
#
#                 background-color:  red;
#
#             }
#
#             #T_6ffbad1a_8622_11e6_bb04_642737f035d1row6_col104 {
#
#                 background-color:  red;
#
#             }
#
#             #T_6ffbad1a_8622_11e6_bb04_642737f035d1row9_col4 {
#
#                 background-color:  red;
#
#             }
#
#             #T_6ffbad1a_8622_11e6_bb04_642737f035d1row9_col5 {
#
#                 background-color:  red;
#
#             }
#
# ...

# %% [markdown]
# <div style="direction:rtl"> <br >
# במבט מהיר על טבלת המידע ניתן לראות את הנתונים ולהתרשם ממספר עמודות שונות. בצבע אדום ניתן לראות תאים עם הערך  "NaN" - ערך חסר. ניגע בנושא הערכים החסרים בהמשך.
# <br />
# </div>

# %% [markdown]
# <h4> עמודות </h4>

# %% [markdown]
# [[back to top](#top)]

# %%
# All distinct features: 
all_feat_set = set([feat for sheet in df for feat in df[sheet] ])
print('In all sheets together, there are %d distinct columns. ' % len(all_feat_set))

# Features present in all sheets: 
intersecting_feats =  set.intersection(*[set(df[sheet].keys()) for sheet in df])
print('There are %d features present in all sheets.' % len(intersecting_feats))
# Out:
# In all sheets together, there are 387 distinct columns.
# There are 84 features present in all sheets.

# %%
# Add number of intersecting features between sheets
intersecting_features = pd.DataFrame()
for ind, s1 in enumerate(sheets): 
    col_name = (str(ind),  ('Intersection with ' + str(s1)))
    sheet_stats[col_name[0]] = [num_intersecting_feats(data = df, sheet1 = s1, sheet2=s2) for s2 in sheets]
    intersecting_features[col_name[1]]=sheet_stats[col_name[0]]
intersecting_features['Sheets'] = sheet_stats['Sheets']
# Reorder columns: 
cols = sheet_stats.columns.tolist()
cols = [cols[1]] + [cols[0]] + cols[2:]
sheet_stats = sheet_stats[cols]

# %%
sheet_stats
# Out:
#                             Sheets  Number of features    0    1    2    3  \
# 0   יישובים בינוניים (2,000-9,999)                 108  108   84   92  104
# 1                        קובץ ארצי                 344   84  344  337  125
# 2   קובץ יישובים גדולים (10,000 +)                 352   92  337  352  130
# 3             קובץ מועצות איזוריות                 148  104  125  130  148
# 4                      קובץ מחוזות                 347   86  340  339  126
# 5                        קובץ נפות                 347   86  339  340  127
#
#      4    5
# 0   86   86
# 1  340  339
# 2  339  340
# 3  126  127
# 4  347  340
# 5  340  347

# %% [markdown]
# <div style="direction:rtl">
# בטבלה מעל, בעמודות הממוספרות, ניתן לראות את מספר העמודות המשותפות לכל שתי כרטיסיות. כך לדוגמא לקובץ יישובים בינוניים יש 84 עמודות משותפות עם הקובץ הארצי. ישנן בכל הגליונות יחד 387 עמודות שונות ו84 עמודות המשותפות לכל הגליונות. עקב מספר העמודות המשותף הנמוך, בחרנו להתמקד בהבנה של כל כרטיסיה בנפרד, ולא בראיה כוללת מתוך הנחה כי ניתוח של העמודות המשותפות יוגבל לחלק קטן מהמידע בלבד.
# </div>
# <a id='1.2.'></a>
# <h4> ערכים חסרים </h4>
# <div style="direction:rtl">
# כפי שציינו וראינו בקובץ היישובים הקטנים, ישנם תאים רבים בהם אין ערך. מעבר לתאים החסרים ישנם מספר ערכים שונים המייצגים משמעויות שונות שאינן ערך מספרי חוקי. בחיפוש באתר המצורף בסוף ההקדמה ניתן למצוא את המקרא הבא:
# </div>

# %%
Image(filename='pictures/nan_val_markings.png', width=650, height=450)

# %% [markdown]
# <div style="direction:rtl">
# ניתן ללמוד עוד על הנתונים והבעיות שלהם בקישור הבא:
# http://cbs.gov.il/publications15/profil_ishuvim09_1580/pdf/symbol_h.pdf
# </div>
#
# <div style="direction:rtl"> <br >
# במחברת זו החלטנו לעסוק בעיקר בהפקת התובנות מהמידע הנתון. פרטי הניקיון ופירוט תהליכי הניקוי והעיבוד המקדים שביצענו זמינים במלואם בקישור הבא
# <a href="https://drive.google.com/open?id=0B7eezotEK_oPQzRkY2lYYm5WSms"> הזה.</a>
# <br />  </div>
#
# <div style="direction:rtl"> <br >
# נסתפק במספר הערות על המידע: על מנת שלא לבחור ערכים לא הגיוניים שיטו תוצאות וכדי למנוע מצב של שימוש בעמודות עם רוב של ערכים חסרים, החלטנו לסנן לחלוטין כל עמוד שהיה חסר בה ערך. העדפנו לאבד עמודות ולשמור על כל השורות כדי להימנע ממצב בו לאוכלוסייה מסויימת לא קיים ערך למדד מסויים וכל הרשומות בהם רוב לאוכלוסייה זו מסוננות מתוך המידע.
# <br />
# </div>
#
# <div style="direction:rtl"> <br >
# בטבלה מתחת ניתן לראות סקירה סופית של מספר הערכים החוקיים בכל כרטיסיה.
# <br />
# </div>

# %%
df_no_header = dict((sheet, df[sheet][1:]) for sheet in sheets)
# Add statistics to sheet_stats without english header: 
sheet_stats['Num of not NaNs'] = [num_cols_no_NaNs(df_no_header, sheet) for sheet in sheets]
sheet_stats['Num of not NaNs or symbol'] = [num_cols_no_NaNs_symbol(df_no_header, sheet) for sheet in sheets]
sheet_stats['Num of not NaNs or symbol or parentheses'] = [num_cols_no_NaNs_symbol_par(df_no_header, sheet) for sheet in sheets]
sheet_stats[['Sheets', 'Number of features', 'Num of not NaNs or symbol or parentheses']]
# Out:
#                             Sheets  Number of features  \
# 0   יישובים בינוניים (2,000-9,999)                 108
# 1                        קובץ ארצי                 344
# 2   קובץ יישובים גדולים (10,000 +)                 352
# 3             קובץ מועצות איזוריות                 148
# 4                      קובץ מחוזות                 347
# 5                        קובץ נפות                 347
#
#    Num of not NaNs or symbol or parentheses
# 0                                        60
# 1                                       300
# 2                                       150
# 3                                       110
# 4                                       307
# 5                                       291

# %% [markdown]
# <div style="direction:rtl">
# ניתן לגשת לקבצי המידע הנקי בקישור
# <a href="https://drive.google.com/open?id=0B7eezotEK_oPQzRkY2lYYm5WSms"> הזה.</a>
# </div>

# %% [markdown]
# <h2> (Principal Component Analysis)
# ניתוח גורמים ראשיים  </h2>
# <p></p>
# <p></p>
# <div style="direction:rtl">
#  ניתוח גורמים ראשיים היא שיטה סטטיסטית למציאת ייצוג מממד נמוך למידע רב ממדי. בלי להכנס לאלגברה הליניארית, ניתן לומר שאנו מחשבים את הוקטורים (קומבינאציות ליניאירות של העמודות הקיימות שיתארו את הכיוונים בהם מוסברת השונות במטריצת הקוורינס. ) <br>
# </div>
# <p></p>
# <div style="direction:rtl">
# ניתן לראות את כל תהליך ניתוח הגורמים הראשיים, פעם אחת באלגברה טכנית ופעם שנייה בעזרת החבילה של פייתון sklearn בסעיף 2.1 של המחברת הבאה: TODO
#  <br>
#  </div>
# <p></p>
# <div style="direction:rtl">
# לקריאה נוספת בויקיפדיה:
# <a href="https://goo.gl/t11pHY">ניתוח גורמיים ראשיים</a>
# </div>

# %% [markdown]
# <a id='2.1.'></a>

# %% [markdown]
# <h3>  Scree plot - ניתוח מקדים של הגורמיים הראשיים  </h3>
#
# <div style="direction:rtl"> <br>
# לפני שנציג את תוצאות ריצת האלגוריתם נעסוק במידת הרלוונטיות של כל גורם ראשי. בתרשים הבא חמש כרטיסיות שונות, אחת לכל לשונית במידע המקורי. כל נקודה מייצגת וקטור חדש שייצרנו מהעמודות המקוריות של לשונית זו, קומבינציות ליניאריות של המדדים המקוריים. הציר האנכי מתאר את אחוז השונות המוסברת ע"י כל וקטור כזה. הקו האדום מסמן את השונות הממוצעת,אם הייתה מוסברת ע"י כל הוקטורים בצורה אחידה. ניתן לראות כי הוקטורים שבחרנו מסבירים את המידע בצורה איכותית ולהבין עבור כל לשונית כמה מגמות שונות קיימות בה.
# <br />
# </div>
#
# <div style="direction:rtl"> <br>
# נציין כי לשונית "קובץ ארצי" לא מופיעה היות ויש בה רשומה אחת בלבד ולכן אין אפשרות לתאר מגמות.
# <br />
# </div>

# %%
# Reading clean data from disk
df_clean = pd.read_excel('/home/noamk/Dropbox/pythonWorkspase/Health/Processed_Data/Clean_Data.xlsx', sheetname=None)

# %%
sheets_no_national = sheets[:1] + sheets[2:]   # Remove national sheet               
plot_scree_tabs(df_clean, sheets_no_national)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0a0e04ee-95c2-4e82-85f1-5fa1119c74f4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# <h7> יש לשים לב למספר הלשוניות השונות בגרף </h7>

# %% [markdown]
# <div style="direction:rtl">
# מעניין לראות כי בלשונית קובץ מחוזות הגורם הראשי הראשון שחישבנו מסביר את רוב השונות, מצב שלא קיים באף לשונית אחרת. מצד שני בלשונית יישובים בינוניים מוסבר חלק קטן יותר מהשונות ע"י הוקטור הראשון. תוצאה ראשונית זו הגיונית לאור העובדה שישנם יישובים קטנים רבים יותר ממחוזות. בעוד על פני מחוז שלם הרבה תופעות קטנות מתמצעות, לכל יישוב קטן את האופי שלו, האוכלוסייה והתנאים הספציפיים שלו.
# </div>

# %% [markdown]
# <div style="direction:rtl">
# בטבלה הבאה מוצגות המגמות הבולטות בכל לשונית. ניתן לראות כי המדד החשוב ביותר לתיאור ואיפיון יישוב גדול לדוגמא, הוא אחוז האוכלוסייה היהודית\ערבית לעומת יישובים בינוניים שבהם דווקא מין וגיל האוכלוסייה הם הפרמטרים המהותיים ביותר.
# </div>

# %%
pd.read_csv('/home/noamk/Dropbox/pythonWorkspase/Health/Processed_Data/PCA_Manual_summed.csv')
# Out:
#                              Sheet  \
# 0   יישובים בינוניים (2,000-9,999)
# 1   קובץ יישובים גדולים (10,000 +)
# 2             קובץ מועצות איזוריות
# 3                      קובץ מחוזות
# 4                        קובץ נפות
#
#                                             Vector_0  \
# 0                             אוכלוסייה לפי מין וגיל
# 1  אוכלוסייה (יהודים-ערבים), אוכלוסייה לפי מין, סרטן
# 2                  אוכלוסייה, שכר ממוצע, חברתי-כלכלי
# 3  בעלי מוגבלויות גמלאות,שחרורים מאשפוז, סרטן, לי...
# 4  סרטן(שד, ערמונית, מעי, ריאות), אוכלוסייה מבוגר...
#
#                                             Vector_1  \
# 0                            פטירות לפי מין2005-2009
# 1                             שחרורים מאשפוז, פטירות
# 2                             שחרורים מאשפוז, פטירות
# 3  שכר, ביטוחי בריאות פרטי, ג'יני, תמותה ומומים ב...
# 4    פטירות, סרטן, תוחלת חיים, קשיי ריכוז, משתקמים,
#
#                                             Vector_2  \
# ...

# %% [markdown]
# <div style="direction:rtl">
# <br> <br />
# בולט במיוחד קובץ הנפות אשר הרכיב הראשון שלו עוסק כולו בסרטן (ערמונית, שד, מעי גס, ריאות ועוד). אף שסרטן הוא פרמטר משמעותי באפיון יישובים גדולים כפי שניתן לראות בוקטור הראשון של קובץ היישובים הגדולים, אין הוא מאפיין את היישובים כפי שהוא מאפיין בצורה בלעדית את הנפות השונות. ניתן להסיק מכך כי הגורמים לסרטן והאזרחים הנפגעים ממנו אינם מלוכדים ע"י עיר אחת, אלא ע"י איזור גיאוגרפי ממוקד - הנפה.
#
# <br> <br />
# חלק גדול מההמלצות שיוצעו במסמך זה יעסוק בחלוקת תחומי אחריות ומשאבים, והנגשת המידע הקיים על מנת לאפשר ייעול של התהליכים הללו בעתיד, בסוגייות השונות. ברור מניתוח זה של הנתונים כי אסור שבעיית שכיחות הסרטן תטופל ע"י כל מחוז בנפרד. כדי להבין את הבעיה לעומקה, לתכנן פתרונות לטווח הקצר והארוך, להתוות מדיניות נכונה ולטפל באזרחים הפגועים יש צורך בגוף על-מחוזי. העיר חיפה הופיעה בחדשות לעיתים רבות בהקשר זה בעוד נפת חיפה כולה סובלת ממקרי סרטן רבים, כפי שנראה בהמשך. חיפה אינה הנפה היחידה בה מקרי הסרטן שכיחים יותר מנפות אחרות ובנפות אלה יש לבצע מיקוד של פעולות למניעה, אבחון מוקדם וטיפול.
# </div>

# %% [markdown]
# <div style="direction:rtl">
# הטבלה מעל היא תוצר של עיבוד ידני של התוצאות המלאות שיוצגו בהמשך. ניתן לראות את המידע כולו בקובץ
# <a href="https://docs.google.com/spreadsheets/d/1rbw5W6k_CM_ijZtvfI5DtApWfwExfOZskm616Uk6JZo/edit#gid=859204616"> הזה.</a>
# תחת הלשונית "PCA_Trends_Full" ניתן למצוא את כל העמודות השונות המרכיבות את הוקטורים החדשים השונים  ואת הטבלה המתומצתת תחת הלשונית "PCA_Manual_summed".
# <br> <br />
# כמובן שניתן לראות את תהליך חישוב ועיבוד התוצאות המלא במחברת
# <a href="TODO"> זו. </a>
# </div>

# %%
processed_pca = pd.read_excel('/home/noamk/Dropbox/pythonWorkspase/Health/Processed_Data/PCA_Trends_10_processed.csv.xlsx', sheetname=None)
proc_pca_man = processed_pca['PCA_Manual_summed']
proc_pca_full = processed_pca['PCA_Trends_manual']

# %%
pd.DataFrame(proc_pca_full['Vector_0'][4].split('\n'), columns=['נפות - גורם ראשי 0'])
# Out:
#                                   נפות - גורם ראשי 0
# 0  מקרים חדשים של סרטן ערמונית בגברים, 2005-2009 ...
# 1  מקרים חדשים של סרטן ריאות לפי מין, 2005-2009 (...
# 2  מקרים חדשים של סרטן שד בנשים, 2005-2009 (שיעור...
# 3  מקרים חדשים של סרטן שד בנשים, 2005-2009 (מספר ...
# 4  מקרים חדשים של סרטן ערמונית בגברים, 2005-2009 ...
# 5     אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-נקבה75+
# 6  מקרים חדשים של סרטן ריאות לפי מין, 2005-2009 (...
# 7  מקרים חדשים של סרטן מעי גס לפי מין, 2005-2009 ...
# 8  מקרים חדשים של סרטן(כל הסוגים)לפי מין, 2005-20...
# 9   אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-נקבה55-64

# %% [markdown]
# <div style="direction:rtl">
# בטבלה מעל מוצגות יחד כל העמודות השונות (מתוך גיליון נפות) שמרכיבות ביחד את הוקטור הראשון בעמודת הנפות. ניתן לראות שכמעט כל הערכים שנבחרו קשורים לסרטן כאשר הערכים שאינם מדדים ישירים של סרטן עוסקים באחוז האוכלוסייה המבוגרת. לא במקרה מופיעים ערכים אלו מופיעים יחד, לנוכוחותם באותה עמוד ישנה משמעות חזקה ביותר. כל קבוצת מדדים המרכיבה יחד וקטור מתארת את אותה המגמה.
# <br> <br \>
# נתאר במילים את המגמה המתוארת ואת המשמעויות שלה על מנת לאפשר הבנה של כל שאר המגמות המתוארות. בגיליון הנפות ישנן 13 נפות שונות (שורה לכל נפה). כל גורם ראשי שקיבלנו מייצג מגמה במידע, קרי, קבוצת פרמטרים זו (כפי שמופיעה בטבלה למעלה) משתנה יחד עבור הנפות השונות. ישנן נפות בהן כל מדדי הסרטן נמוכים וישנן נפות בהן כל מדדי הסרטן גבוהים. חשוב לשים לב כי אף שבדוגמה זו רוב הערכים עוסקים באותו נושא, אין זה מתחייב כלל.
# </div>

# %% [markdown]
# <h3> ניתוח גליונות פרטני וויזואליזציה של התוצאות </h3>

# %% [markdown]
# <h4> דיוקן אישי - קובץ נפות </h4>
# <div style="direction:rtl">

# %%
sheet_name_heb = 'קובץ נפות'
hover_var='שם נפה'
row_ind_in_proc_pca_man = proc_pca_man[proc_pca_man['Sheet']==sheet_name_heb].index.tolist()[0]
proc_pca_man.iloc[[row_ind_in_proc_pca_man]]
# Out:
#        Sheet                                           Vector_0  \
# 4  קובץ נפות  סרטן(שד, ערמונית, מעי, ריאות), אוכלוסייה מבוגר...
#
#                                           Vector_1                  Vector_2  \
# 4  פטירות, סרטן, תוחלת חיים, קשיי ריכוז, משתקמים,   פטירת תינוקות, לידות מום
#
#                                        Vector_3                 Vector_4
# 4  שחרורים מאשפוז, מוגבלויות, סרטן, אוכלוסייה,   שחרורים מאשפוז, משתקמים

# %%
pca_sin_sheet = single_sheet_pca(sheet_name_heb, proc_pca_full)
pca_sin_sheet
# Out:
#                                          גורם ראשי 0  \
# 0  מקרים חדשים של סרטן ערמונית בגברים, 2005-2009 ...
# 1  מקרים חדשים של סרטן ריאות לפי מין, 2005-2009 (...
# 2  מקרים חדשים של סרטן שד בנשים, 2005-2009 (שיעור...
# 3  מקרים חדשים של סרטן שד בנשים, 2005-2009 (מספר ...
# 4  מקרים חדשים של סרטן ערמונית בגברים, 2005-2009 ...
# 5     אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-נקבה75+
# 6  מקרים חדשים של סרטן ריאות לפי מין, 2005-2009 (...
#
#                                          גורם ראשי 1  \
# 0  פטירות לפי גיל ומין2005-2009 (שיעור ל- 1,000תו...
# 1  פטירות לפי סיבות מוות2005-2009 (שיעור מתוקנן ל...
# 2      רווח סמך לתוחלת חיים בלידה, (זכר) -גבול עליון
# 3  תקנון פטירות2005-2009 (שיעור מתוקנן ל- 1,000תו...
# 4  פטירות לפי גיל ומין2005-2009 (שיעור ל- 1,000תו...
# 5  מקרים חדשים של סרטן מעי גס לפי מין, 2005-2009 ...
# 6                  תוחלת חיים בלידה, 2005-2009 (זכר)
#
#                                          גורם ראשי 2  \
# ...

# %%
pca_sin_sheet.iat[2,0]
# Out:
# 'מקרים חדשים של סרטן שד בנשים, 2005-2009 (שיעור מתוקנן ל- 100,000תושבים),רווח סמך גבול תחתון'

# %%
x_s = [pca_sin_sheet.iat[0,0], pca_sin_sheet.iat[0,0], pca_sin_sheet.iat[1,0], pca_sin_sheet.iat[3,0]]
y_s = [pca_sin_sheet.iat[2,0], pca_sin_sheet.iat[0,1], pca_sin_sheet.iat[0,1], pca_sin_sheet.iat[5,0]]
min_sizes = [5, 5, 0.2, 5]
data_dicts = create_data_dicts(x_s, y_s, min_sizes, sheet_name_heb, df_clean, df, 
                  size_='אוכלוסייה ממוצעת2010 (אלפים)', color_= 'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
                  hover_=hover_var)
plot_scatter_tabs(data_dicts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-1112c76f5fca> in <module>()
#       5                   size_='אוכלוסייה ממוצעת2010 (אלפים)', color_= 'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
#       6                   hover_=hover_var)
# ----> 7 plot_scatter_tabs(data_dicts)
#
# TypeError: plot_scatter_tabs() missing 1 required positional argument: 'sheet_names_heb'

# %% [markdown]
# <h7> יש לשים לב למספר הלשוניות השונות בגרף בינהן ניתן לעבור בלחיצה. ריחוף מעל דגימה עם העכבר יעלה מידע נוסף על דגימה זו.
# <br> <br />
# <b> בעזרת סרגל הכלים מצד שמאל ניתן להתקרב ולהתרחק, לגרור ולהזיז את התרשים, לשנות את גודלו ולחזור למצב המקורי. </b>
# </h7>

# %% [markdown]
# <div style="direction:rtl">
# בסדרת הגרפים מעלה מתוארות מספר תופעות מטרידות.
# <br> <br />
# בגרף A מראה כי בנפות מסויימות יש סרטן יותר מבאחרות, ושהיכן שיש סרטן שד לנשים, יש גם יותר מקרי סרטן ערמונית לגברים.
# תופעה סמוייה בגרף הזה המוצגת בצבע הנקודות מראה כי דווקא בנפות בעלות אחוז ערבים גבהוה יותר ישנם פחות מקרים חדשים של סרטן. על פניו, ניתן לפרש את גרף A בצורה מעודדת מבחינת פערים חברתיים כלכליים.
#
# <br> <br />
# בגרף B, המציג את מספר מקרי סרטן הערמונית החדשים לצד שיעור התמותה המתוקנן אנו עדים לתופעה חריגה. מלבד נפת חיפה, מצד ימין למעלה, כל הנפות בעלות התמותה הגבוהה ביותר הן נפות בעלות אחוז תושבים ערבים גבוהה. מסקנה מתבקשת אפשרית היא שהערבים תושבי עכו וחדרה חולים חולים בסרטן באותה מידה בה חולים התושבים היהודים אך מאובחנים פחות.
#
# <br> <br />
# גרף C, המציג את אותה המגמה בדיוק מחזק את הטענות הקודמות. חיזוק משמעותי לטענה כי מתקיים אבחון חסר לסרטן ומחלות אחרות הקשורות לזיהום מתקבל מנפת גולן, הנמצאת בפינה השמאלית למטה בכל שלושת הגרפים. כאשר מוסר איום הזיהום אמנם אין איבחונים של סרטן, אך גם אין תמותה.
# <br> <br />
# לבסוף, בגרף D אנו רואים כי אף שמספר מקרי סרטן השד החדשים בקרב נשים הוא הגדול ביותר, דווקא בנפת חיפה חוץ מספר אחוז גבוהה של נשים מעל גיל 75. ניתן לקוות שבעזרת מודעות, התגוננות ואיבחון מוקדם ניתן לשנות את המצב הקיים.
# <br> <br />
# נתייחס בפרק המסקנות לדרכי פעולה אפשריות.
#
# </div>

# %% [markdown]
# <h4> דיוקן אישי - קובץ יישובים גדולים </h4>
# <div style="direction:rtl">

# %%
sheet_name_heb = 'קובץ יישובים גדולים (10,000 +)'
hover_var = 'שם יישוב'
row_ind_in_proc_pca_man = proc_pca_man[proc_pca_man['Sheet']==sheet_name_heb].index.tolist()[0]
proc_pca_man.iloc[[row_ind_in_proc_pca_man]]
# Out:
#                             Sheet  \
# 1  קובץ יישובים גדולים (10,000 +)
#
#                                             Vector_0                Vector_1  \
# 1  אוכלוסייה (יהודים-ערבים), אוכלוסייה לפי מין, סרטן  שחרורים מאשפוז, פטירות
#
#                                           Vector_2  \
# 1  לידות חי, רשומים לשרותים\nאוכלוסייה\nריבוי טבעי
#
#                                             Vector_3                Vector_4
# 1  אוכלוסייה, רשומים  לשרותים חברתיים, פריון, אשפ...  שחרורים מאשפוז, פטירות

# %%
pca_sin_sheet = single_sheet_pca(sheet_name_heb, proc_pca_full)
pca_sin_sheet
# Out:
#                                          גורם ראשי 0  \
# 0       אוכלוסייה ממוצעת של יהודים ואחרים2010 (אחוז)
# 1               אוכלוסייה ממוצעת של ערבים2010 (אחוז)
# 2              אוכלוסייה ממוצעת של יהודים2010 (אחוז)
# 3    אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-נקבה5-14
# 4  מקרים חדשים של סרטן(כל הסוגים)לפי מין, 2005-20...
# 5    אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-זכר55-64
# 6  אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-סך הכל5...
#
#                                          גורם ראשי 1  \
# 0  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 1  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 2  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 3  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 4  פטירות לפי גיל ומין2005-2009 (שיעור ל- 1,000תו...
# 5  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 6  פטירות לפי סיבות מוות2005-2009 (שיעור מתוקנן ל...
#
#                                          גורם ראשי 2  \
# ...

# %%
x_s = [pca_sin_sheet.iat[0,3], pca_sin_sheet.iat[4,0], pca_sin_sheet.iat[4,0],]
y_s = [pca_sin_sheet.iat[2,4], pca_sin_sheet.iat[0,1], pca_sin_sheet.iat[4,1],]
min_sizes = [0.2, 5, 5, 1300]
data_dicts = create_data_dicts(x_s, y_s, min_sizes, sheet_name_heb, df_clean, df, 
                  size_='אוכלוסייה ממוצעת2010 (אלפים)', color_= 'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
                  hover_=hover_var)
plot_scatter_tabs(data_dicts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-6e6feee546b2> in <module>()
#       5                   size_='אוכלוסייה ממוצעת2010 (אלפים)', color_= 'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
#       6                   hover_=hover_var)
# ----> 7 plot_scatter_tabs(data_dicts)
#
# TypeError: plot_scatter_tabs() missing 1 required positional argument: 'sheet_names_heb'

# %% [markdown]
# <h7> יש לשים לב למספר הלשוניות השונות בגרף בינהן ניתן לעבור בלחיצה. ריחוף מעל דגימה עם העכבר יעלה מידע נוסף על דגימה זו.
# <br> <br />
# <b> בעזרת סרגל הכלים מצד שמאל ניתן להתקרב ולהתרחק, לגרור ולהזיז את התרשים, לשנות את גודלו ולחזור למצב המקורי. </b>
# </h7>

# %% [markdown]
# <div style="direction:rtl">
# מגרף A - בעיה באזור עכו נהרייה ואזור צפת שגורמת לריבוי שחרורים מאשפוז. צריך לבדוק לעומק למה זה קורה שם ואיך צריך לתגבר את ההערכות הספיציפית. כנראה קשור לבתי החולים כי קורה גם באיזור עכו-נהרייה-ירכא, בהם סרטן יכול להיות גורם משפיע, אבל גם בצפת, שם פחות קיים סרטן. לבסוף, תושבי נצרת שגם הם יחסית גבוהה במדד השחרורים מאשפוז נמצאים בין שתי הנפות ומקבלים שירות רפואי בשתיהן. חשוב לבדוק את בתי החולים וההיערכות הרפואית באיזור.
# <br> <br />
# מגרף B עולה שוב תופעת האיבחון הלקוי של סרטן בקרב האוכלוסייה הערבית. עולה גם חלוקה בתוך האוכלוסייה הערבית כך שרוב היישובים הערבים שקרובים למרכז הגרף נמצאים בצפון הארץ ומרכזה ואילו האוכלוסייה הדרומית פחות מאובחנת.
# <br> <br />
# גרף C, במקרה זה מפריך את המסקנות הראשוניות מגרף B. ברפרוף עם העכבר ניתן לראות כי דווקא היישובים הערבים שהראו יותר מקרי אבחון של סרטן הם גם היישובים עם אחוז התמותה הגבוהה יותר.
# יישוב חריג מבחינה זו הוא תל שבע שבדרום. ניכר כי קיים בו אחוז תמותה גבוהה כמו במקומות עם שכיחות הסרטן הגבוהה יותר.
# נתייחס ללמצא זה בהמלצות.
# </div>

# %% [markdown]
# <h4> דיוקן אישי - מועצות איזוריות  </h4>
# <div style="direction:rtl">

# %%
sheet_name_heb = 'קובץ מועצות איזוריות'
hover_var = 'שם מועצה אזורית'
row_ind_in_proc_pca_man = proc_pca_man[proc_pca_man['Sheet']==sheet_name_heb].index.tolist()[0]
proc_pca_man.iloc[[row_ind_in_proc_pca_man]]
# Out:
#                   Sheet                           Vector_0  \
# 2  קובץ מועצות איזוריות  אוכלוסייה, שכר ממוצע, חברתי-כלכלי
#
#                  Vector_1                                           Vector_2  \
# 2  שחרורים מאשפוז, פטירות  אוכלוסייה ממוצעת, אוכלוסייה, ריבוי טבעי\nרשומי...
#
#                                            Vector_3  \
# 2  אוכלוסייהת קופות חולים, שכר (גברים), קופות חולים
#
#                                             Vector_4
# 2  סוגי נזקקות,קופות חולים, ממוצע יהודים, אוכלוסי...

# %%
pca_sin_sheet = single_sheet_pca(sheet_name_heb, proc_pca_full)
pca_sin_sheet
# Out:
#                                          גורם ראשי 0  \
# 0    אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-נקבה5-14
# 1  אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-סך הכל5-14
# 2                        שכר ממוצע לחודש, 2009 -נשים
# 3                                מדד חברתי-כלכלי2008
# 4     אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-זכר5-14
# 5                              אשכול חברתי-כלכלי2008
# 6  אוכלוסייה לפי מין וגיל2005-2009 (אחוז)-סך הכל5...
#
#                                          גורם ראשי 1  \
# 0  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 1  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 2  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 3  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 4  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 5  שחרורים מאשפוז כללי לפי גיל ומין2005-2009, (שי...
# 6  פטירות לפי מין2005-2009 (שיעור ל- 1,000תושבים)...
#
#                                          גורם ראשי 2  \
# ...

# %%
data_dict = {'sheet_name': 'קובץ יישובים גדולים (10,000 +)',
            'sheet': df_clean['קובץ יישובים גדולים (10,000 +)'], 
             'original_sheet': df['קובץ יישובים גדולים (10,000 +)'], 
             'x_var':'אוכלוסייה ממוצעת של יהודים ואחרים2010 (אחוז)',
             'y_var':'מאושפזים באשפוז פסיכיאטרי2005-2009 (שיעור ל- 100,000תושבים),שיעור מתוקנן,שני המינים,סך הכל15+,רווח סמך גבול עליון',
             'size_var': 'אוכלוסייה ממוצעת של יהודים ואחרים2010 (אחוז)',
             'color_var': 'רשומים במחלקות לשרותים חברתיים ובעלי נזקקות מוגדרת,2005-2009,רשומים(שיעור ל-1,000)',

             'hover_var': 'שם יישוב',}

# %%
x_s = [pca_sin_sheet.iat[2,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0]]
y_s = [pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[0,1], pca_sin_sheet.iat[5,3], pca_sin_sheet.iat[2,0], pca_sin_sheet.iat[5,2]]
min_sizes = [70, 0.1, 0.1, 0.1, 0.1]
data_dicts = create_data_dicts(x_s, y_s, min_sizes, sheet_name_heb, df_clean, df, 
                  size_='אוכלוסייה ממוצעת2010 (אלפים)', color_= 'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
                  hover_=hover_var)
plot_scatter_tabs(data_dicts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-e75860c8e7ed> in <module>()
#       5                   size_='אוכלוסייה ממוצעת2010 (אלפים)', color_= 'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
#       6                   hover_=hover_var)
# ----> 7 plot_scatter_tabs(data_dicts)
#
# TypeError: plot_scatter_tabs() missing 1 required positional argument: 'sheet_names_heb'

# %% [markdown]
# <div style="direction:rtl">
# מגרף A מצטיירת תמונה כי בקרב היישובים הערבים קיים בלי יוצא מן הכלל אחוז גבוהה של נערות צעירות וצעירים באופן כללי. מרפרוף עם העכבר אפשר לראות שהיישובים עם אחוז האוכלוסייה הגבוהה הנמצאים גם הם גבוהה הם היישובים החרדים - ביתר עילית, מודיעין עילית, אלעד בני ברק וכו'. ניתן להניח שרבות מהמסקנות הממוקדות שלנו עבור האוכלוסייה הערבית ביישובים הגדולים ונערות אוכלוסייה זו בפרט, תהיינה תקפות גם עבור תושבי היישובים החרדים המפורטים מעלה.
# </div>

# %% [markdown]
# <h4> דיוקן אישי - יישובים בינוניים  </h4>

# %%
sheet_name_heb = 'יישובים בינוניים (2,000-9,999)'
hover_var = 'שם יישוב'
row_ind_in_proc_pca_man = proc_pca_man[proc_pca_man['Sheet']==sheet_name_heb].index.tolist()[0]
proc_pca_man.iloc[[row_ind_in_proc_pca_man]]

# %%
proc_pca_man['Sheet']=='יישובים בינוניים (2,000-9,999)'

# %%
proc_pca_man

# %%
pca_sin_sheet = single_sheet_pca(sheet_name_heb, proc_pca_full)
pca_sin_sheet

# %%
x_s = [pca_sin_sheet.iat[2,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0]]
y_s = [pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[0,1], pca_sin_sheet.iat[5,3], pca_sin_sheet.iat[2,0], pca_sin_sheet.iat[5,2]]
min_sizes = [70, 0.1, 0.1, 0.1, 0.1]
data_dicts = create_data_dicts(x_s, y_s, min_sizes, sheet_name_heb, df_clean, df, 
                  size_='אוכלוסייה ממוצעת2010 (אלפים)', color_= 'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
                  hover_=hover_var)
plot_scatter_tabs(data_dicts)

# %% [markdown]
# <div style="direction:rtl">
# מגרף A מצטיירת תמונה כי בקרב היישובים הערבים קיים בלי יוצא מן הכלל אחוז גבוהה של נערות צעירות וצעירים באופן כללי. מרפרוף עם העכבר אפשר לראות שהיישובים עם אחוז האוכלוסייה הגבוהה הנמצאים גם הם גבוהה הם היישובים החרדים - ביתר עילית, מודיעין עילית, אלעד בני ברק וכו'. ניתן להניח שרבות מהמסקנות הממוקדות שלנו עבור האוכלוסייה הערבית ביישובים הגדולים ונערות אוכלוסייה זו בפרט, תהיינה תקפות גם עבור תושבי היישובים החרדים המפורטים מעלה.
# </div>

# %% [markdown]
# <h4> דיוקן אישי - מחוזות  </h4>
# בפרק זה נציג את

# %%
sheet_name_heb = 'קובץ מחוזות'
hover_var = 'שם מחוז'
row_ind_in_proc_pca_man = proc_pca_man[proc_pca_man['Sheet']==sheet_name_heb].index.tolist()[0]
proc_pca_man.iloc[[row_ind_in_proc_pca_man]]

# %%
pca_sin_sheet = single_sheet_pca(sheet_name_heb, proc_pca_full)
pca_sin_sheet

# %%
x_s = [pca_sin_sheet.iat[0,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[3,0]]
y_s = [pca_sin_sheet.iat[3,0], pca_sin_sheet.iat[0,1], pca_sin_sheet.iat[5,3], pca_sin_sheet.iat[2,0], pca_sin_sheet.iat[5,2]]
min_sizes = [0.005, 10, 0.1, 0.1, 0.1]
data_dicts = create_data_dicts(x_s, y_s, min_sizes, sheet_name_heb, df_clean, df, 
                  size_='אוכלוסייה ממוצעת2010 (אלפים)', color_= 'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
                  hover_=hover_var)
plot_scatter_tabs(data_dicts)

# %% [markdown]
# <div style="direction:rtl">
# מגרף A מצטיירת תמונה כי בקרב היישובים הערבים קיים בלי יוצא מן הכלל אחוז גבוהה של נערות צעירות וצעירים באופן כללי. מרפרוף עם העכבר אפשר לראות שהיישובים עם אחוז האוכלוסייה הגבוהה הנמצאים גם הם גבוהה הם היישובים החרדים - ביתר עילית, מודיעין עילית, אלעד בני ברק וכו'. ניתן להניח שרבות מהמסקנות הממוקדות שלנו עבור האוכלוסייה הערבית ביישובים הגדולים ונערות אוכלוסייה זו בפרט, תהיינה תקפות גם עבור תושבי היישובים החרדים המפורטים מעלה.
# </div>

# %% [markdown]
# <h2> :מסקנות </h2>

# %% [markdown]
# <div style="direction:rtl">
# בפרק זה ניגע בתופעות שזיהינו בדיוקנות השונים וננסח המלצות ודרכי פעולה אפשריות לטיפול בתופעה.
# <br> <br />
# <b> נפות </b>
# <br> <br />
#
# הראינו כי קיימת מצוקה של איבחון סרטנים שונים העולה בצורה ברורה מהנתונים. בנוסף ראינו כי הבעיה אינו אזורית אלא כלל ארצית. יש לפעול במספר מישורים כדי לטפל בבעיה זו מהשורש.
# <br> <br />
# 1) פנים ערבית: יש להראות את המצב לראשי הקהילה השונים ולעורר מודעות בקרבם לבעיה. יש צורך בקמפיין ממוקד לאוכלוסייה לפי האזורים הדחופים (עכו, חדרה, עמק יזראל) והנחייה של האזרחים כיצד עליהם לפעול ומה הכללים שעליהם לאמץ על מנת להגן על עצמם.
# 2) רפואית: יש להנחות את הצוותים הרפואיים באיזורים אלו, החל מבתי החולים ודרך המרפאות הקהילתיות להכיר בסוגייה ולפעול כדי להדריך ולהסביר את הקהילה הערבית לצד דריכות ואיבחון מוקדם יותר של מקרי החולי.
#
# <br> <br />
# <b> יישובים גדולים </b>
# ראינו כי מסיבה כלשהי קיימת תמותה חריגה ביישוב תל שבע שבדרום למרות שאינה באזור עם שכיחות סרטן גבוהה. סביר מאוד כי קיימת בעיה נקודתית אשר אפשר לפתוח בעזרת מודעות, התגוננות, אבחון מוקדם וחינוך לשמירה על הסביבה ואורך חיים בריא. מומלץ מחקר ממוקד וטיפול מדוייק שיכול להביא לתוצאות מהירות והקלה גדולה לתושבים ולמערכות הבריאות העמוסות באזור.
#
# יש צורך לעשות בדיוק נקודתית באשר לסיבות המוות ביישוב זה ולהגדיר טיפול ממוקד בשיתוף עם הקהילה.
# <br> <br />
#
# הראינו כי קיימת בעיה באיזורים צפת ועכו נהרייה במספר השחרורים מאישפוז. נתון מדאיג אך מסתמן כאפשרי לטיפול. היות ושני האיזורים שונים מבחינות זיהומיות, כפי שראינו בקובץ הנפות, סביר שבעזרת היערכות, תקצוב ומעקב צמוד אחרי כוח האדם הרפואי באזור, ניתן יהיה להביא לשיפור משמעותי בבעיות אלה.
# </div>

# %%
# TODO: 
#1) Add other params to display with hover
#2) Add heatmap bar for color of dots
#3) Add legend for size of dots
def toolTip_scatter_5d(sheet, original_sheet, x_var, y_var, size_var, color_var, hover_var, sheet_name, min_size=4, return_p=True):
    sum_size = sum(sheet[size_var])
    source = ColumnDataSource(
        data=dict(
            x = [x for x in sheet[x_var]], 
            y = [x for x in sheet[y_var]],
            size_norm =  [min_size + 2*min_size*x/sum_size for x in sheet[size_var]], 
            size_ = [x for x in sheet[size_var]],
            #color_ = [5 + 5*x for x in sheet[color_var]],
            color_ = ["#%02x%02x%02x" % (int(r), int(g), int(b)) for r, g, b, _ in 
                                255*mpl.cm.viridis(mpl.colors.Normalize()(sheet[color_var]))],
            color_hover = [x for x in sheet[color_var]],
            hover_title = [x for x in original_sheet[hover_var]][1:],)) #In original sheet first english row not removed

    hover = HoverTool(
        tooltips=[
            ("Name", "@hover_title"),
            (color_var+' (color)', '@color_hover'),
            (size_var+ ' (radius)', "@size_"),
            ("(x,y)", "($x, $y)"),])
#             ("Frequency", "@frequency"),]) # TODO: remove fo
    TOOLS = 'pan, box_zoom,box_select,resize,reset, wheel_zoom'

    p = figure(title='ייצוג דו-ממדי של '+ sheet_name,
                tools=TOOLS, plot_width=700, plot_height=400, )
    p.add_tools(hover)
    p.xaxis[0].axis_label = x_var
    if len(y_var)>30: 
        p.yaxis[0].axis_label = y_var[:30]

        #         t= y_var.split(' ')
#         t.insert(int(len(y_var.split(' '))/2), ' \n\r ')
#         p.yaxis[0].axis_label = ''.join(t)
         #' '.split(y_var).insert(int(len(' '.split(y_var))/2), '\n')
    else: 
        p.yaxis[0].axis_label = y_var
#     text_font_size = "25px"
    p.scatter('x', 'y', radius='size_norm', color='color_',
              source=source,fill_alpha=0.6,) #fill_color=colors,
    p.title.align = "center"
    p.title.text_font_size = "25px"
    if return_p: 
        return p
    else: 
        show(p)

# %%
def plot_scatter_tabs(data_dicts): 
    print('גודל דגימות: ,', data_dicts[0]['size_var'])
    print('צבע דגימות: ,', data_dicts[0]['color_var'])
    tabs = [Panel(child=toolTip_scatter_5d(**data_dict, return_p=True), title=str(ind)) for ind, data_dict in 
            zip([x for x in 'ABCDEFGHIJ'], data_dicts)]
    tabs = Tabs(tabs=list(tabs))
    show(tabs)

# %%
data_dict1 = {'sheet_name': sheet_name_heb,
             'sheet': df_clean[sheet_name_heb], 
             'original_sheet': df[sheet_name_heb], 
             'x_var':'שכר ממוצע לחודש, 2009 -גברים',
             'y_var':pca_sin_sheet.iat[5,0],
             'size_var':'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
             'color_var': 'אוכלוסייה ממוצעת2010 (אלפים)',
             'hover_var': hover_var,
             'min_size': 50,}

data_dict2 = {'sheet_name': sheet_name_heb,
             'sheet': df_clean[sheet_name_heb], 
             'original_sheet': df[sheet_name_heb], 
             'x_var':pca_sin_sheet.iat[2,0],
             'y_var':pca_sin_sheet.iat[3,0],
             'size_var':'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
             'color_var': 'אוכלוסייה ממוצעת2010 (אלפים)',
             'hover_var': hover_var,
             'min_size': 50,}

data_dict3 = {'sheet_name': sheet_name_heb,
             'sheet': df_clean[sheet_name_heb], 
             'original_sheet': df[sheet_name_heb], 
             'x_var':pca_sin_sheet.iat[2,0],
             'y_var':pca_sin_sheet.iat[5,0],
             'size_var':'אוכלוסייה ממוצעת של ערבים2010 (אחוז)',
             'color_var': 'אוכלוסייה ממוצעת2010 (אלפים)',
             'hover_var': hover_var,
              'min_size': 50,}
plot_scatter_tabs([data_dict1, data_dict2, data_dict3, ])
# Out:
# גודל דגימות: , אוכלוסייה ממוצעת של ערבים2010 (אחוז)
# צבע דגימות: , אוכלוסייה ממוצעת2010 (אלפים)
#     <div class="bk-root">
#         <div class="plotdiv" id="8958dbdf-c58e-4007-8ae2-ff1c6e705204"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
# ...

# %%
data_dict = {'sheet_name': 'קובץ יישובים גדולים (10,000 +)',
            'sheet': df_clean['קובץ יישובים גדולים (10,000 +)'], 
             'original_sheet': df['קובץ יישובים גדולים (10,000 +)'], 
             'x_var':'אוכלוסייה ממוצעת של יהודים ואחרים2010 (אחוז)',
             'y_var':'מאושפזים באשפוז פסיכיאטרי2005-2009 (שיעור ל- 100,000תושבים),שיעור מתוקנן,שני המינים,סך הכל15+,רווח סמך גבול עליון',
             'size_var': 'אוכלוסייה ממוצעת של יהודים ואחרים2010 (אחוז)',
             'color_var': 'רשומים במחלקות לשרותים חברתיים ובעלי נזקקות מוגדרת,2005-2009,רשומים(שיעור ל-1,000)',

             'hover_var': 'שם יישוב',}
toolTip_scatter_5d(**data_dict)

# %%
data_dict = {'sheet': df_clean['קובץ יישובים גדולים (10,000 +)'], 
             'original_sheet': df['קובץ יישובים גדולים (10,000 +)'], 
             'x_var':'לידות חי2010 (מספר מוחלט)',
             'y_var':'רשומים במחלקות לשרותים חברתיים ובעלי נזקקות מוגדרת,2005-2009,רשומים(מספר ממוצע)',
             'size_var': 'אוכלוסייה ממוצעת של יהודים ואחרים2010 (אחוז)',
             'color_var': 'רשומים במחלקות לשרותים חברתיים ובעלי נזקקות מוגדרת,2005-2009,רשומים(שיעור ל-1,000)',

             'hover_var': 'שם יישוב',}
toolTip_scatter_5d(**data_dict)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2e9a77b3-66a4-4cbb-9b66-f1c7d5af4337"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
data_dict = {'sheet': df_clean['קובץ מחוזות'], 
             'original_sheet': df['קובץ מחוזות'], 
             'x_var':'בעלי מוגבלויות,2008, מתקשים מאוד או אינם יכוליםלראות(אחוז מבני5 ומעלה) - נקבה',
             'y_var':'מקבלי גמלאות מהביטוח הלאומי, 2009 -ניידות בכל הגילים(אחוז מבני אותו גיל)',
             'size_var': 'מקרים חדשים של סרטן(כל הסוגים)לפי מין, 2005-2009 (שיעור מתוקנן ל- 100,000תושבים),זכר,רווח סמך גבול תחתון',
             'color_var': 'מקרים חדשים של סרטן(כל הסוגים)לפי מין, 2005-2009 (שיעור מתוקנן ל- 100,000תושבים),זכר,רווח סמך גבול תחתון',
             'hover_var': 'שם מחוז',}
toolTip_scatter_5d(**data_dict)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="36e47261-2bbb-467f-98f1-52a200f66353"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %% [markdown]
# <a id='3.3.'></a>

# %% [markdown]
# <h2> תרומת העבודה  </h2>
#
# <div style="direction:rtl"> <br>
# ניתן לחלק את תרומת העבודה למספר תחומים באופן הבא.
# </div>
# <div style="direction:rtl"> <br>
# עיבוד מקדים: עותק של המידע המעובד זמין בקישור הבא: TODO
# הקוד לניקוי והכנת המידע המתאים לכל טבלה כמו המידע הנתון זמין (והיה זמין מרגע שהיה מוכן) בקישור כאן TODO
# </div>
#
# <div style="direction:rtl"> <br>
# ניתוח גורמים מרכזיים:
# ניתן למצוא את הגורמים הראשיים בקובץ זה. בנוסף ניתן לראות את הסיכום הידני שבוצע לכל וקטור לכדי צמצום של מספר מילות מפתח.
# TODO - LINK TO WORDS
# https://docs.google.com/spreadsheets/d/1rbw5W6k_CM_ijZtvfI5DtApWfwExfOZskm616Uk6JZo/edit?usp=sharing
# גם במקרה זה זמין הקוד בקישור הזה. TODO_ADD LINK
# </div>
# <div style="direction:rtl"> <br>
# אספקט נוסף בתרומת העבודה הוא הויזואליזציות. כמו כל שאר הקוד בעיבוד זה, הויזואליזציות נכתבו כפונקציות גנריות המקבלות מקורות מידע ועמודות רצויות ומציגות את המידע המבוקש. מעבר לגרפים האינטרקטיביים שהצגנו בעבודה זו, יצרנו כלים ידידותיים לשימוש עתידי פשוט בלי צורך להבין את הקוד. </div>
#
# <div style="direction:rtl"> <br>
#  TODO התייחסות להמלצות
# </div>

# %%
from IPython.core.display import HTML
HTML("""
<style>

div.cell { /* Tunes the space between cells */
margin-top:1em;
margin-bottom:1em;
}

div.text_cell_render h1 { /* Main titles bigger, centered */
font-size: 1.5em;
line-height:1.4em;
text-align:center;
}

div.text_cell_render h2 { /*  Parts names nearer from text */
margin-bottom: -0.4em;
}


div.text_cell_render { /* Customize text cells */
font-family: 'Times New Roman';
font-size:1.5em;
line-height:1.4em;
padding-left:3em;
padding-right:3em;
text-align:right;
}
</style>
""")
# Out:
# <style>
#
# div.cell { /* Tunes the space between cells */
# margin-top:1em;
# margin-bottom:1em;
# }
#
# div.text_cell_render h1 { /* Main titles bigger, centered */
# font-size: 1.5em;
# line-height:1.4em;
# text-align:center;
# }
#
# div.text_cell_render h2 { /*  Parts names nearer from text */
# margin-bottom: -0.4em;
# }
#
#
# div.text_cell_render { /* Customize text cells */
# font-family: 'Times New Roman';
# font-size:1.5em;
# line-height:1.4em;
# padding-left:3em;
# padding-right:3em;
# text-align:right;
# }
# </style>
